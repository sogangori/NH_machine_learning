# %%
import pandas as pd #별칭

# %%
c = 1 + 2
c
# Out:
# 3

# %%
c + 2
# Out:
# 5

# %%
path = 'C:/Users/student/Downloads/NH_ML/datasets/housing.csv' #절대경로

# %%
# .tab  (shift + tab)  C(omma)S(eparated)V(values)
df = pd.read_csv('./datasets/housing.csv')# 상대경로    '.':현재홀더, '..' 상위 폴더
df.shape #(행, 열)
# Out:
# (20640, 10)

# %%
df.columns # 컬럼
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %%
df.index # 인덱스
# Out:
# RangeIndex(start=0, stop=20640, step=1)

# %%
df.values # 데이터
# Out:
# array([[-122.23, 37.88, 41.0, ..., 8.3252, 452600.0, 'NEAR BAY'],
#        [-122.22, 37.86, 21.0, ..., 8.3014, 358500.0, 'NEAR BAY'],
#        [-122.24, 37.85, 52.0, ..., 7.2574, 352100.0, 'NEAR BAY'],
#        ...,
#        [-121.22, 39.43, 17.0, ..., 1.7, 92300.0, 'INLAND'],
#        [-121.32, 39.43, 18.0, ..., 1.8672, 84700.0, 'INLAND'],
#        [-121.24, 39.37, 16.0, ..., 2.3886, 89400.0, 'INLAND']],
#       dtype=object)

# %%
#Data Frame : 컬럼, 인덱스, 데이터로 구성
#head(), tail(), sample(n)
df.head(1)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY

# %%
df.shape #(행, 열)
# Out:
# (20640, 10)

# %%
df.info()#정보 보기
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
# longitude             20640 non-null float64
# latitude              20640 non-null float64
# housing_median_age    20640 non-null float64
# total_rooms           20640 non-null float64
# total_bedrooms        20433 non-null float64
# population            20640 non-null float64
# households            20640 non-null float64
# median_income         20640 non-null float64
# median_house_value    20640 non-null float64
# ocean_proximity       20640 non-null object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
housing = df
housing['ocean_proximity'].value_counts()#값이 몇번 등장하는지 세기 (문자만 가능)
# Out:
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %%
housing['ocean_proximity'].value_counts().plot.pie() #범주는 파이 그래프

# %%
#카테고리 종류가 많을 때
housing['ocean_proximity'].value_counts().plot.barh() #bar수직막대, barh 수평막대

# %%
housing['total_rooms'].head(2) # 특정 컬럼만 읽을 때
# Out:
# 0     880.0
# 1    7099.0
# Name: total_rooms, dtype: float64

# %%
# 컬럼 몇개만 읽을 때 [리스트] 
housing[ ['total_rooms', 'ocean_proximity'] ].head(2)
# Out:
#    total_rooms ocean_proximity
# 0        880.0        NEAR BAY
# 1       7099.0        NEAR BAY

# %%
housing.describe() #통계 요약 (수치 데이터만)
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
#그래프가 안나올때 
# %matplotlib inline 
h = housing.hist(bins=10, figsize=(15,10)) #단위 : 인치

# %%
housing.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %%
housing.drop(columns='median_house_value').boxplot(figsize=(15,5))

# %%
housing[['population', 'median_house_value']].boxplot(figsize=(15,5))

# %%
housing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
housing.plot(x='longitude',y='latitude', style='.')

# %%
housing.corr() # 상관 관계 correlation
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924664           -0.108197     0.044568
# latitude            -0.924664  1.000000            0.011173    -0.036100
# housing_median_age  -0.108197  0.011173            1.000000    -0.361262
# total_rooms          0.044568 -0.036100           -0.361262     1.000000
# total_bedrooms       0.069608 -0.066983           -0.320451     0.930380
# population           0.099773 -0.108785           -0.296244     0.857126
# households           0.055310 -0.071035           -0.302916     0.918484
# median_income       -0.015176 -0.079809           -0.119034     0.198050
# median_house_value  -0.045967 -0.144160            0.105623     0.134153
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.069608    0.099773    0.055310      -0.015176
# latitude                 -0.066983   -0.108785   -0.071035      -0.079809
# ...

# %%
#데이터 일부만
p = pd.plotting.scatter_matrix(housing.iloc[:100, 2:6], figsize=(10,10))

# %%
# 두개의 컬럼관의 관계를 점으로 표현
p = pd.plotting.scatter_matrix(housing.iloc[:100], figsize=(20,20))

# %%
#누락데이터 isna() 널이냐? NA, NAN(Not a number), NAS(Not a String)
housing.isna().sum() # True > 1 변환 되어서 컬럼 별 합을 구합니다
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %%
housing = housing.dropna() # 누락값이 있는 행을 제거

# %%
# 교사학습 : 입력데이터 / 출력데이터 분리
y = housing['median_house_value'] # 예측할 타겟
x = housing.iloc[:, :-2] #integer location ,: 모든행  , :-2 뒤에서 두개 열 빼고 
x.shape, y.shape
# Out:
# ((20433, 8), (20433,))

# %%
# 학습용 / 테스트 용 분리 (80/20)     m: 데이터(샘플) 갯수,   n : 특징 수
m_train = int(len(x) * 0.8) #length
m_train
# Out:
# 16346

# %%
x_train = x.iloc[:m_train] # 0~16512
y_train = y.iloc[:m_train]
x_test = x.iloc[m_train:] #16512~끝까지
y_test = y.iloc[m_train:]
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((16346, 8), (16346,), (4087, 8), (4087,))

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model.fit(x_train, y_train) # 누락데이터가 있으면 연산이 안되므로 학습이 안됩니다
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
model.score(x_train, y_train)#R^2 결정계수 1이 최선
# Out:
# 0.6179115278983921

# %%
model.score(x_test, y_test) #일반화가 잘되었다.
# Out:
# 0.6919099384697789

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,5))
plt.plot(y_test.values, label='Real')
plt.plot(model.predict(x_test.values), label='predict')
plt.legend()# '레이블 표시'
